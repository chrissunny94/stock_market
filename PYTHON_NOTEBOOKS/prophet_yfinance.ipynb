# %% [markdown]
# #### Install yfinance

# %%
# !pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yfinance in /home/chris/.local/lib/python3.10/site-packages (0.2.28)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.1.0)
# Requirement already satisfied: numpy>=1.16.5 in /home/chris/.local/lib/python3.10/site-packages (from yfinance) (1.24.3)
# Requirement already satisfied: requests>=2.31 in /home/chris/.local/lib/python3.10/site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in /home/chris/.local/lib/python3.10/site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /home/chris/.local/lib/python3.10/site-packages (from yfinance) (4.9.3)
# Requirement already satisfied: appdirs>=1.4.4 in /usr/lib/python3/dist-packages (from yfinance) (1.4.4)
# Requirement already satisfied: pytz>=2022.5 in /home/chris/.local/lib/python3.10/site-packages (from yfinance) (2023.3.post1)
# Requirement already satisfied: frozendict>=2.3.4 in /home/chris/.local/lib/python3.10/site-packages (from yfinance) (2.3.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/chris/.local/lib/python3.10/site-packages (from yfinance) (4.12.2)
# Requirement already satisfied: html5lib>=1.1 in /usr/lib/python3/dist-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in /home/chris/.local/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.4.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2023.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/chris/.local/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.31->yfinance) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3/dist-packages (from requests>=2.31->yfinance) (1.26.5)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests>=2.31->yfinance) (2020.6.20)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.16.0)

# %% [markdown]
# # Forecasting Stocks from Yahoo Finance with Prophet

# %%
import yfinance as yf

# berkshire hathaway inc. (b stock)
brk = yf.Ticker('TCS')

hist = brk.history(period="1d" , interval="1m", auto_adjust=True)

hist
# Out:
# /home/chris/.local/lib/python3.10/site-packages/yfinance/utils.py:631: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quotes.loc[idx2, "Open"] = quotes["Open"][n - 1]
# /home/chris/.local/lib/python3.10/site-packages/yfinance/utils.py:633: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if not _np.isnan(quotes["High"][n - 1]):
# /home/chris/.local/lib/python3.10/site-packages/yfinance/utils.py:634: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quotes.loc[idx2, "High"] = _np.nanmax([quotes["High"][n - 1], quotes["High"][n - 2]])
# /home/chris/.local/lib/python3.10/site-packages/yfinance/utils.py:638: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   if not _np.isnan(quotes["Low"][n - 1]):
# /home/chris/.local/lib/python3.10/site-packages/yfinance/utils.py:639: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quotes.loc[idx2, "Low"] = _np.nanmin([quotes["Low"][n - 1], quotes["Low"][n - 2]])
# /home/chris/.local/lib/python3.10/site-packages/yfinance/utils.py:643: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quotes.loc[idx2, "Close"] = quotes["Close"][n - 1]
# /home/chris/.local/lib/python3.10/site-packages/yfinance/utils.py:645: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quotes.loc[idx2, "Adj Close"] = quotes["Adj Close"][n - 1]
# /home/chris/.local/lib/python3.10/site-packages/yfinance/utils.py:646: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   quotes.loc[idx2, "Volume"] += quotes["Volume"][n - 1]
#                              Open    High     Low   Close  Volume  Dividends  \
# Datetime
# 2023-09-25 09:30:00-04:00  2.0200  2.0200  2.0200  2.0200    7079        0.0
# 2023-09-25 09:31:00-04:00  2.0100  2.0100  1.9600  1.9700   26509        0.0
# 2023-09-25 09:33:00-04:00  2.0000  2.0000  2.0000  2.0000     193        0.0
# 2023-09-25 09:34:00-04:00  1.9900  1.9900  1.9900  1.9900     100        0.0
# 2023-09-25 09:35:00-04:00  1.9900  1.9900  1.9900  1.9900     248        0.0
# ...                           ...     ...     ...     ...     ...        ...
# 2023-09-25 10:50:00-04:00  1.9800  1.9850  1.9800  1.9850       0        0.0
# 2023-09-25 10:52:00-04:00  1.9891  1.9891  1.9891  1.9891     252        0.0
# 2023-09-25 10:55:00-04:00  1.9700  1.9700  1.9700  1.9700    1350        0.0
# 2023-09-25 10:59:00-04:00  1.9650  1.9650  1.9600  1.9600    2410        0.0
# 2023-09-25 11:00:00-04:00  1.9600  1.9600  1.9600  1.9600       0        0.0
#
#                            Stock Splits
# Datetime
# 2023-09-25 09:30:00-04:00           0.0
# 2023-09-25 09:31:00-04:00           0.0
# 2023-09-25 09:33:00-04:00           0.0
# 2023-09-25 09:34:00-04:00           0.0
# 2023-09-25 09:35:00-04:00           0.0
# ...                                 ...
# 2023-09-25 10:50:00-04:00           0.0
# 2023-09-25 10:52:00-04:00           0.0
# 2023-09-25 10:55:00-04:00           0.0
# 2023-09-25 10:59:00-04:00           0.0
# 2023-09-25 11:00:00-04:00           0.0
#
# [64 rows x 7 columns]

# %%
import pandas as pd

df = pd.DataFrame()

df['ds'] = hist.index
df['y'] = hist['Close'].values

df.tail()
# Out:
#                           ds       y
# 59 2023-09-25 10:50:00-04:00  1.9850
# 60 2023-09-25 10:52:00-04:00  1.9891
# 61 2023-09-25 10:55:00-04:00  1.9700
# 62 2023-09-25 10:59:00-04:00  1.9600
# 63 2023-09-25 11:00:00-04:00  1.9600

# %%
# !pip3 install --upgrade pip
# !pip3 install fbprophet
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pip in /home/chris/.local/lib/python3.10/site-packages (23.2.1)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting fbprophet
#   Using cached fbprophet-0.7.1.tar.gz (64 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Cython>=0.22 in /home/chris/.local/lib/python3.10/site-packages (from fbprophet) (3.0.2)
# Collecting cmdstanpy==0.9.5 (from fbprophet)
#   Using cached cmdstanpy-0.9.5-py3-none-any.whl (37 kB)
# Collecting pystan>=2.14 (from fbprophet)
#   Using cached pystan-3.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: numpy>=1.15.4 in /home/chris/.local/lib/python3.10/site-packages (from fbprophet) (1.24.3)
# Requirement already satisfied: pandas>=1.0.4 in /usr/local/lib/python3.10/dist-packages (from fbprophet) (2.1.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /usr/lib/python3/dist-packages (from fbprophet) (3.5.1)
# Requirement already satisfied: LunarCalendar>=0.0.9 in /home/chris/.local/lib/python3.10/site-packages (from fbprophet) (0.0.9)
# Requirement already satisfied: convertdate>=2.1.2 in /home/chris/.local/lib/python3.10/site-packages (from fbprophet) (2.4.0)
# Requirement already satisfied: holidays>=0.10.2 in /home/chris/.local/lib/python3.10/site-packages (from fbprophet) (0.33)
# Collecting setuptools-git>=1.2 (from fbprophet)
#   Using cached setuptools_git-1.2-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: python-dateutil>=2.8.0 in /usr/local/lib/python3.10/dist-packages (from fbprophet) (2.8.2)
# Requirement already satisfied: tqdm>=4.36.1 in /home/chris/.local/lib/python3.10/site-packages (from fbprophet) (4.65.0)
# Requirement already satisfied: pymeeus<=1,>=0.3.13 in /home/chris/.local/lib/python3.10/site-packages (from convertdate>=2.1.2->fbprophet) (0.5.12)
# Requirement already satisfied: ephem>=3.7.5.3 in /home/chris/.local/lib/python3.10/site-packages (from LunarCalendar>=0.0.9->fbprophet) (4.1.4)
# Requirement already satisfied: pytz in /home/chris/.local/lib/python3.10/site-packages (from LunarCalendar>=0.0.9->fbprophet) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.4->fbprophet) (2023.3)
# Collecting aiohttp<4.0,>=3.6 (from pystan>=2.14->fbprophet)
#   Obtaining dependency information for aiohttp<4.0,>=3.6 from https://files.pythonhosted.org/packages/3e/f6/fcda07dd1e72260989f0b22dde999ecfe80daa744f23ca167083683399bc/aiohttp-3.8.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached aiohttp-3.8.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.7 kB)
# Collecting clikit<0.7,>=0.6 (from pystan>=2.14->fbprophet)
#   Using cached clikit-0.6.2-py2.py3-none-any.whl (91 kB)
# Collecting httpstan<4.11,>=4.10 (from pystan>=2.14->fbprophet)
#   Obtaining dependency information for httpstan<4.11,>=4.10 from https://files.pythonhosted.org/packages/95/fe/3861743c0ec4aed8b2fb9e5251344acba0aad13092f97c8db900b6616590/httpstan-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached httpstan-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.2 kB)
# Collecting pysimdjson<6.0.0,>=5.0.2 (from pystan>=2.14->fbprophet)
#   Using cached pysimdjson-5.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
# Requirement already satisfied: setuptools in /home/chris/.local/lib/python3.10/site-packages (from pystan>=2.14->fbprophet) (68.2.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.0->fbprophet) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/lib/python3/dist-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (21.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /home/chris/.local/lib/python3.10/site-packages (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (3.2.0)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet)
#   Using cached multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
# Collecting async-timeout<5.0,>=4.0.0a3 (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet)
#   Obtaining dependency information for async-timeout<5.0,>=4.0.0a3 from https://files.pythonhosted.org/packages/a7/fa/e01228c2938de91d47b307831c62ab9e4001e747789d0b05baf779a6488c/async_timeout-4.0.3-py3-none-any.whl.metadata
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting yarl<2.0,>=1.0 (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet)
#   Using cached yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet)
#   Obtaining dependency information for frozenlist>=1.1.1 from https://files.pythonhosted.org/packages/1e/28/74b8b6451c89c070d34e753d8b65a1e4ce508a6808b18529f36e8c0e2184/frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata
#   Using cached frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet)
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting crashtest<0.4.0,>=0.3.0 (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet)
#   Using cached crashtest-0.3.1-py3-none-any.whl (7.0 kB)
# Collecting pastel<0.3.0,>=0.2.0 (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet)
#   Using cached pastel-0.2.1-py2.py3-none-any.whl (6.0 kB)
# Collecting pylev<2.0,>=1.3 (from clikit<0.7,>=0.6->pystan>=2.14->fbprophet)
#   Using cached pylev-1.4.0-py2.py3-none-any.whl (6.1 kB)
# Requirement already satisfied: appdirs<2.0,>=1.4 in /usr/lib/python3/dist-packages (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet) (1.4.4)
# Collecting marshmallow<4.0,>=3.10 (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet)
#   Obtaining dependency information for marshmallow<4.0,>=3.10 from https://files.pythonhosted.org/packages/ed/3c/cebfdcad015240014ff08b883d1c0c427f2ba45ae8c6572851b6ef136cad/marshmallow-3.20.1-py3-none-any.whl.metadata
#   Using cached marshmallow-3.20.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting webargs<9.0,>=8.0 (from httpstan<4.11,>=4.10->pystan>=2.14->fbprophet)
#   Obtaining dependency information for webargs<9.0,>=8.0 from https://files.pythonhosted.org/packages/19/62/ae934b85a0aa35c25c4aea820174a871b948642b0c75b3f73d7868938b00/webargs-8.3.0-py3-none-any.whl.metadata
#   Using cached webargs-8.3.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: packaging>=17.0 in /usr/lib/python3/dist-packages (from marshmallow<4.0,>=3.10->httpstan<4.11,>=4.10->pystan>=2.14->fbprophet) (21.3)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.0->aiohttp<4.0,>=3.6->pystan>=2.14->fbprophet) (3.3)
# Using cached aiohttp-3.8.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
# Using cached httpstan-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (44.4 MB)
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Using cached frozenlist-1.4.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (225 kB)
# Using cached marshmallow-3.20.1-py3-none-any.whl (49 kB)
# Using cached webargs-8.3.0-py3-none-any.whl (31 kB)
# Building wheels for collected packages: fbprophet
#   Building wheel for fbprophet (setup.py) ... error
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [57 lines of output]
#       /tmp/pip-install-yo9jmje_/fbprophet_16a750e7e2094c46a5c9b10339bf3e1b/setup.py:10: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#         from pkg_resources import (
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build/lib
#       creating build/lib/fbprophet
#       creating build/lib/fbprophet/stan_model
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "/tmp/pip-install-yo9jmje_/fbprophet_16a750e7e2094c46a5c9b10339bf3e1b/setup.py", line 122, in <module>
#           setup(
#         File "/home/chris/.local/lib/python3.10/site-packages/setuptools/__init__.py", line 103, in setup
#           return distutils.core.setup(**attrs)
#         File "/home/chris/.local/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 185, in setup
#           return run_commands(dist)
#         File "/home/chris/.local/lib/python3.10/site-packages/setuptools/_distutils/core.py", line 201, in run_commands
#           dist.run_commands()
#         File "/home/chris/.local/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/home/chris/.local/lib/python3.10/site-packages/setuptools/dist.py", line 989, in run_command
#           super().run_command(command)
#         File "/home/chris/.local/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/home/chris/.local/lib/python3.10/site-packages/wheel/bdist_wheel.py", line 364, in run
#           self.run_command("build")
#         File "/home/chris/.local/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/home/chris/.local/lib/python3.10/site-packages/setuptools/dist.py", line 989, in run_command
#           super().run_command(command)
#         File "/home/chris/.local/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/home/chris/.local/lib/python3.10/site-packages/setuptools/_distutils/command/build.py", line 131, in run
#           self.run_command(cmd_name)
#         File "/home/chris/.local/lib/python3.10/site-packages/setuptools/_distutils/cmd.py", line 318, in run_command
#           self.distribution.run_command(command)
#         File "/home/chris/.local/lib/python3.10/site-packages/setuptools/dist.py", line 989, in run_command
#           super().run_command(command)
#         File "/home/chris/.local/lib/python3.10/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/tmp/pip-install-yo9jmje_/fbprophet_16a750e7e2094c46a5c9b10339bf3e1b/setup.py", line 48, in run
#           build_models(target_dir)
#         File "/tmp/pip-install-yo9jmje_/fbprophet_16a750e7e2094c46a5c9b10339bf3e1b/setup.py", line 36, in build_models
#           from fbprophet.models import StanBackendEnum
#         File "/tmp/pip-install-yo9jmje_/fbprophet_16a750e7e2094c46a5c9b10339bf3e1b/fbprophet/__init__.py", line 8, in <module>
#           from fbprophet.forecaster import Prophet
#         File "/tmp/pip-install-yo9jmje_/fbprophet_16a750e7e2094c46a5c9b10339bf3e1b/fbprophet/forecaster.py", line 17, in <module>
#           from fbprophet.make_holidays import get_holiday_names, make_holidays_df
#         File "/tmp/pip-install-yo9jmje_/fbprophet_16a750e7e2094c46a5c9b10339bf3e1b/fbprophet/make_holidays.py", line 14, in <module>
#           import fbprophet.hdays as hdays_part2
#         File "/tmp/pip-install-yo9jmje_/fbprophet_16a750e7e2094c46a5c9b10339bf3e1b/fbprophet/hdays.py", line 924, in <module>
#           class TU(Turkey):
#         File "/home/chris/.local/lib/python3.10/site-packages/holidays/registry.py", line 175, in __init__
#           raise TypeError(
#       TypeError: This is a python-holidays entity loader class. For entity inheritance purposes please import a class you want to derive from directly: e.g., `from holidays.countries import Entity` or `from holidays.financial import Entity`.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for fbprophet
#   Running setup.py clean for fbprophet
# Failed to build fbprophet
# ERROR: Could not build wheels for fbprophet, which is required to install pyproject.toml-based projects

# %%
#from fbprophet import Prophet
from prophet import Prophet

#m = Prophet(daily_seasonality=False)
model = Prophet()
model.fit(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/chris/STOCK_MARKET/stock_market/PYTHON_NOTEBOOKS/prophet_yfinance.ipynb Cell 7 line 6
#       <a href='vscode-notebook-cell:/home/chris/STOCK_MARKET/stock_market/PYTHON_NOTEBOOKS/prophet_yfinance.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a> #m = Prophet(daily_seasonality=False)
#       <a href='vscode-notebook-cell:/home/chris/STOCK_MARKET/stock_market/PYTHON_NOTEBOOKS/prophet_yfinance.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> model = Prophet()
# ----> <a href='vscode-notebook-cell:/home/chris/STOCK_MARKET/stock_market/PYTHON_NOTEBOOKS/prophet_yfinance.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a> model.fit(df)
#
# File ~/.local/lib/python3.10/site-packages/prophet/forecaster.py:1126, in Prophet.fit(self, df, **kwargs)
#    1123     raise ValueError('Dataframe has less than 2 non-NaN rows.')
#    1124 self.history_dates = pd.to_datetime(pd.Series(df['ds'].unique(), name='ds')).sort_values()
# -> 1126 history = self.setup_dataframe(history, initialize_scales=True)
#    1127 self.history = history
#    1128 self.set_auto_seasonalities()
#
# File ~/.local/lib/python3.10/site-packages/prophet/forecaster.py:273, in Prophet.setup_dataframe(self, df, initialize_scales)
#     271 df['ds'] = pd.to_datetime(df['ds'])
#     272 if df['ds'].dt.tz is not None:
# --> 273     raise ValueError(
#     274         'Column ds has timezone specified, which is not supported. '
#     275         'Remove timezone.'
#     276     )
#     277 if df['ds'].isnull().any():
#     278     raise ValueError('Found NaN in column ds.')
#
# ValueError: Column ds has timezone specified, which is not supported. Remove timezone.

# %%
future = m.make_future_dataframe(365, freq='D')

forecast = m.predict(future)

forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(7)

# %%
m.plot(forecast);

# %% [markdown]
# ## Make it a Function

# %%
def make_forecast(ticker, periods, hist='max'):
    """
    forecast the given ticker (stock) period days into the future (from today)

    inputs
    ------
    > ticker
        >> ticker of stock to forecast
    > periods
        >> number of days into the future to forecast (from today's date)
    > hist
        >> amount of historical data to consider
            > default: max
            > options: 1d, 5d, 1mo, 3mo, 6mo, 1y, 2y, 5y, 10y, ytd, max
    """
    # pull historical data from yahoo finance
    stock_data = yf.Ticker(ticker)

    hist_data = stock_data.history(hist, auto_adjust=True)

    # create new dataframe to hold dates (ds) & adjusted closing prices (y)
    df = pd.DataFrame()

    df['ds'] = hist_data.index.values
    df['y'] = hist_data['Close'].values

    # create a Prophet model from that data
    m = Prophet(daily_seasonality=False)
    m.fit(df)

    future = m.make_future_dataframe(periods, freq='D')

    forecast = m.predict(future)

    m.plot(forecast)

    return forecast

# %% [markdown]
# #### Make some Forecasts with that Function

# %%
# kkr real estate finance trust
make_forecast('KREF', 180)

# %%
# dave & buster's
make_forecast('PLAY', 365 * 2).tail()

# %%
n = 365  # set variable for number of days to predict

# snapchat
snap_forecast = make_forecast('SNAP', n)

# only keep the future forecast, and forget most columns
snap_forecast = snap_forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail(n)

snap_forecast
